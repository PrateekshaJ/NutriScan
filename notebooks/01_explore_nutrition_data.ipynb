# %% [markdown]
# # NutriScan — Nutrition Data Exploration
#
# Use this notebook to explore `data/nutrition_db.csv` and validate profiles before training.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

import pandas as pd
from src.nutrition_engine import NutritionEngine

engine = NutritionEngine(ROOT / "data" / "nutrition_db.csv")
df = engine.profiles_dataframe()
df.head()

# %%
df.describe()
